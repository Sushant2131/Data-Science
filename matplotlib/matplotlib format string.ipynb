# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,42,54,33,45,23,40]
a=[1,2,3,4,5,6,7]
b=[50,42,54,30,45,22,44]

# %%
p1=plt.bar(x,y)
p2=plt.plot(a,b,'dy--',gapcolor='r',fillstyle='left')
'''
dr-- = d means diamond shape,r means red color,-- means the line
https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
'''
# Out:
# '\ndr-- = d means diamond shape,r means red color,-- means the line\nhttps://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html\n'

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
np.random.seed(212)
n = 100
rng = np.random.default_rng()
xs = rng.uniform(23, 32, n)
ys = rng.uniform(0, 100, n)
zs = rng.uniform(-50, -25, n)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs, ys, zs)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()
