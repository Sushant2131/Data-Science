# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
company=['amazon','microsoft','google','flipkart','facebook','samsung']
profit=[90,92,101,136,50,99.5]
revenue=[102,111,134,150,124,140]

# %%
plt.bar(company,a )


plt.bar(a-0.2,revenue,width=0.4,label='revenue',color='green' )
plt.bar(a+0.2,profit ,width=0.4,label='profit',color='red')
plt.legend()

# %%
a=np.arange(len(company))
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
plt.bar(a ,company)
plt.ylabel('company')
plt.xlabel('profit in millions')

plt.barh(a,revenue,label='revenue',color='green' )
plt.barh(a,profit ,label='profit',color='red')
plt.legend()
