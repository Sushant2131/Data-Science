# %%
import seaborn as sns 
import pandas as pd

# %%
df=pd.read_excel('CARS.xlsx').dropna()
df.head()
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# 2            4               4.0         Automatic                57.0
# 3            4               7.0         Automatic                60.0
# 4            4               7.0         Automatic                57.0
#
#    body_type  rating  starting_price  ending_price  max_torque_nm  \
# ...

# %%
df.max_power_bhp.value_counts().head()
# Out:
# 187.74    10
# 88.50      6
# 147.51     4
# 65.71      3
# 335.25     3
# Name: max_power_bhp, dtype: int64

# %%
sns.set_style('whitegrid')
data=df
sns.boxplot(x='max_power_bhp',data=df)
# Out:
# <Axes: xlabel='max_power_bhp'>

# %%
df.max_power_bhp.describe()
# Out:
# count    202.000000
# mean     264.869406
# std      192.415872
# min       10.800000
# 25%      108.522500
# 50%      187.740000
# 75%      379.170000
# max      788.520000
# Name: max_power_bhp, dtype: float64

# %%
a=sns.boxplot(x='fuel_tank_capacity',y='fuel_type',hue='transmission_type',data=df)
              
a
# Out:
# <Axes: xlabel='fuel_tank_capacity', ylabel='fuel_type'>

# %%
df.describe()
# Out:
#        reviews_count  engine_displacement  no_cylinder  seating_capacity  \
# count     202.000000           202.000000   202.000000        202.000000
# mean      119.267327          2297.564356     4.693069          5.014851
# std       315.002374          1492.784722     2.534312          1.161050
# min         1.000000             0.000000     0.000000          2.000000
# 25%         5.000000          1334.750000     4.000000          5.000000
# 50%        14.500000          1991.000000     4.000000          5.000000
# 75%        84.000000          2995.750000     6.000000          5.000000
# max      2392.000000          6750.000000    12.000000          8.000000
#
#        fuel_tank_capacity      rating  starting_price  ending_price  \
# count          202.000000  202.000000    2.020000e+02  2.020000e+02
# mean            46.015842    4.433168    9.267619e+06  1.095233e+07
# std             28.918283    0.280793    1.336973e+07  1.537045e+07
# ...
