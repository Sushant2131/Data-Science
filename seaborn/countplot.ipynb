# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('diamonds').dropna()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
a=sns.countplot(x='cut',data=df)
a.bar_label(a.containers[0])
# Out:
# [Text(0, 0, '21551'),
#  Text(0, 0, '13791'),
#  Text(0, 0, '12082'),
#  Text(0, 0, '4906'),
#  Text(0, 0, '1610')]

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.cut.cat.categories
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
df.cut.value_counts().index
# Out:
# CategoricalIndex(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], categories=['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], ordered=False, dtype='category')

# %%
a=sns.countplot(x='cut',data=df)
df.cut.value_counts().index
a.bar_label(a.containers[0])
# Out:
# [Text(0, 0, '21551'),
#  Text(0, 0, '13791'),
#  Text(0, 0, '12082'),
#  Text(0, 0, '4906'),
#  Text(0, 0, '1610')]

# %%
sns.countplot(x='cut',data=df)
df.cut.value_counts().index[::-1]
df.bar_label(a.containers[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 3
#       1 sns.countplot(x='cut',data=df)
#       2 df.cut.value_counts().index[::-1]
# ----> 3 df.bar_label(a.containers[0])
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'bar_label'
