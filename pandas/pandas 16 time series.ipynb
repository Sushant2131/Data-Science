# %%
import pandas as pd
df=pd.read_csv('TCS.BO.csv',parse_dates=['Date'],index_col='Date')
df.head(5)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11256\3337220765.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df=pd.read_csv('TCS.BO.csv',parse_dates=['Date'],index_col='Date')
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-06  3385.000000  3388.000000  3342.500000  3356.500000  3281.893555
# 2022-02-06  3357.000000  3432.250000  3350.050049  3422.949951  3346.866455
# 2022-03-06  3454.699951  3477.500000  3431.550049  3438.800049  3362.364258
# 2022-06-06  3421.000000  3453.100098  3378.000000  3430.250000  3354.004150
# 2022-07-06  3420.000000  3420.000000  3356.199951  3362.000000  3287.271240
#
#               Volume
# Date
# 2022-01-06  121714.0
# 2022-02-06  104828.0
# 2022-03-06   65791.0
# 2022-06-06   34827.0
# 2022-07-06   26386.0

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
 df.index
# Out:
# DatetimeIndex(['2022-01-06', '2022-02-06', '2022-03-06', '2022-06-06',
#                '2022-07-06', '2022-08-06', '2022-09-06', '2022-10-06',
#                '2022-06-13', '2022-06-14',
#                ...
#                '2023-05-19', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-29', '2023-05-30',
#                '2023-05-31', '2023-01-06'],
#               dtype='datetime64[ns]', name='Date', length=249, freq=None)

# %%
df['2022-02'].Close.mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11256\696777583.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2022-02'].Close.mean()
# 3304.9299804

# %%
df["2023-05-23":"2023-05-30"].dropna()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-05-23  3308.000000  3328.949951  3290.449951  3295.699951  3295.699951
# 2023-05-24  3268.000000  3317.350098  3268.000000  3301.050049  3301.050049
# 2023-05-25  3290.000000  3305.649902  3267.850098  3294.750000  3294.750000
# 2023-05-26  3288.050049  3339.000000  3288.050049  3329.000000  3329.000000
# 2023-05-30  3317.000000  3326.300049  3302.000000  3314.800049  3314.800049
#
#              Volume
# Date
# 2023-05-23  32867.0
# 2023-05-24  11292.0
# 2023-05-25  30397.0
# 2023-05-26  66787.0
# 2023-05-30  39929.0

# %%
# %matplotlib inline
df.Close.resample('Q').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.Close.plot()
# Out:
# <Axes: xlabel='Date'>
