# %%
import pandas as pd
df= pd.read_csv('student.csv',header=1)
df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four  75.0  female
# 1    2     Max Ruin  Three  85.0    male
# 2    3       Arnold  Three  55.0    male
# 3    4   Krish Star   Four  60.0     NaN
# 4    5    John Mike   Four  60.0  female
# 5    6    Alex John   Four  55.0    male
# 6    7  My John Rob  Fifth  78.0    male
# 7    8       Asruid   Five  85.0    male
# 8    9      Tes Qry    Six   NaN    male
# 9   10     Big John   Four  55.0  female
# 10  11       Ronald    Six   NaN  female
# 11  12        Recky    Six  94.0  female
# 12  13          Kty  Seven  88.0  female
# 13  14         Bigy  Seven  88.0  female
# 14  15     Tade Row   Four  88.0    male
# 15  16        Gimmy   Four  88.0    male
# 16  17        Tumyu    Six   NaN    male
# 17  18        Honny   Five  75.0    male
# 18  19        Tinny   Nine  18.0    male
# 19  20       Jackly   Nine  65.0  female
# 20  21   Babby John   Four   NaN  female
# 21  22       Reggid  Seven  55.0  female
# 22  23        Herod  Eight  79.0    male
# 23  24    Tiddy Now    NaN  78.0    male
# 24  25     Giff Tow  Seven   NaN    male
# 25  26       Crelea  Seven  79.0     NaN
# 26  27     Big Nose  Three   NaN  female
# 27  28    Rojj Base  Seven  86.0  female
# 28  29  Tess Played  Seven  55.0    male
# 29  30    Reppy Red    Six  79.0  female
# 30  31  Marry Toeey   Four  88.0    male
# 31  32    Binn Rott  Seven   NaN  female
# 32  33    Kenn Rein    Six  96.0  female
# 33  34     Gain Toe  Seven  69.0    male
# 34  35   Rows Noump    Six  88.0     NaN

# %%
new_df=df.fillna(0)
new_df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four  75.0  female
# 1    2     Max Ruin  Three  85.0    male
# 2    3       Arnold  Three  55.0    male
# 3    4   Krish Star   Four  60.0       0
# 4    5    John Mike   Four  60.0  female
# 5    6    Alex John   Four  55.0    male
# 6    7  My John Rob  Fifth  78.0    male
# 7    8       Asruid   Five  85.0    male
# 8    9      Tes Qry    Six   0.0    male
# 9   10     Big John   Four  55.0  female
# 10  11       Ronald    Six   0.0  female
# 11  12        Recky    Six  94.0  female
# 12  13          Kty  Seven  88.0  female
# 13  14         Bigy  Seven  88.0  female
# 14  15     Tade Row   Four  88.0    male
# 15  16        Gimmy   Four  88.0    male
# 16  17        Tumyu    Six   0.0    male
# 17  18        Honny   Five  75.0    male
# 18  19        Tinny   Nine  18.0    male
# 19  20       Jackly   Nine  65.0  female
# 20  21   Babby John   Four   0.0  female
# 21  22       Reggid  Seven  55.0  female
# 22  23        Herod  Eight  79.0    male
# 23  24    Tiddy Now      0  78.0    male
# 24  25     Giff Tow  Seven   0.0    male
# 25  26       Crelea  Seven  79.0       0
# 26  27     Big Nose  Three   0.0  female
# 27  28    Rojj Base  Seven  86.0  female
# 28  29  Tess Played  Seven  55.0    male
# 29  30    Reppy Red    Six  79.0  female
# 30  31  Marry Toeey   Four  88.0    male
# 31  32    Binn Rott  Seven   0.0  female
# 32  33    Kenn Rein    Six  96.0  female
# 33  34     Gain Toe  Seven  69.0    male
# 34  35   Rows Noump    Six  88.0       0

# %%
new_df=df.fillna({
    'class':'class not specified',
    'mark':0,
    'gender':'gender is not specified'
})
new_df
# Out:
#     id         name                class  mark                   gender
# 0    1     John Deo                 Four  75.0                   female
# 1    2     Max Ruin                Three  85.0                     male
# 2    3       Arnold                Three  55.0                     male
# 3    4   Krish Star                 Four  60.0  gender is not specified
# 4    5    John Mike                 Four  60.0                   female
# 5    6    Alex John                 Four  55.0                     male
# 6    7  My John Rob                Fifth  78.0                     male
# 7    8       Asruid                 Five  85.0                     male
# 8    9      Tes Qry                  Six   0.0                     male
# 9   10     Big John                 Four  55.0                   female
# 10  11       Ronald                  Six   0.0                   female
# 11  12        Recky                  Six  94.0                   female
# 12  13          Kty                Seven  88.0                   female
# 13  14         Bigy                Seven  88.0                   female
# 14  15     Tade Row                 Four  88.0                     male
# 15  16        Gimmy                 Four  88.0                     male
# 16  17        Tumyu                  Six   0.0                     male
# 17  18        Honny                 Five  75.0                     male
# 18  19        Tinny                 Nine  18.0                     male
# 19  20       Jackly                 Nine  65.0                   female
# 20  21   Babby John                 Four   0.0                   female
# 21  22       Reggid                Seven  55.0                   female
# 22  23        Herod                Eight  79.0                     male
# 23  24    Tiddy Now  class not specified  78.0                     male
# 24  25     Giff Tow                Seven   0.0                     male
# 25  26       Crelea                Seven  79.0  gender is not specified
# 26  27     Big Nose                Three   0.0                   female
# 27  28    Rojj Base                Seven  86.0                   female
# 28  29  Tess Played                Seven  55.0                     male
# 29  30    Reppy Red                  Six  79.0                   female
# 30  31  Marry Toeey                 Four  88.0                     male
# 31  32    Binn Rott                Seven   0.0                   female
# 32  33    Kenn Rein                  Six  96.0                   female
# 33  34     Gain Toe                Seven  69.0                     male
# 34  35   Rows Noump                  Six  88.0  gender is not specified

# %%
new1_df=df.fillna(method='ffill')
new1_df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four  75.0  female
# 1    2     Max Ruin  Three  85.0    male
# 2    3       Arnold  Three  55.0    male
# 3    4   Krish Star   Four  60.0    male
# 4    5    John Mike   Four  60.0  female
# 5    6    Alex John   Four  55.0    male
# 6    7  My John Rob  Fifth  78.0    male
# 7    8       Asruid   Five  85.0    male
# 8    9      Tes Qry    Six  85.0    male
# 9   10     Big John   Four  55.0  female
# 10  11       Ronald    Six  55.0  female
# 11  12        Recky    Six  94.0  female
# 12  13          Kty  Seven  88.0  female
# 13  14         Bigy  Seven  88.0  female
# 14  15     Tade Row   Four  88.0    male
# 15  16        Gimmy   Four  88.0    male
# 16  17        Tumyu    Six  88.0    male
# 17  18        Honny   Five  75.0    male
# 18  19        Tinny   Nine  18.0    male
# 19  20       Jackly   Nine  65.0  female
# 20  21   Babby John   Four  65.0  female
# 21  22       Reggid  Seven  55.0  female
# 22  23        Herod  Eight  79.0    male
# 23  24    Tiddy Now  Eight  78.0    male
# 24  25     Giff Tow  Seven  78.0    male
# 25  26       Crelea  Seven  79.0    male
# 26  27     Big Nose  Three  79.0  female
# 27  28    Rojj Base  Seven  86.0  female
# 28  29  Tess Played  Seven  55.0    male
# 29  30    Reppy Red    Six  79.0  female
# 30  31  Marry Toeey   Four  88.0    male
# 31  32    Binn Rott  Seven  88.0  female
# 32  33    Kenn Rein    Six  96.0  female
# 33  34     Gain Toe  Seven  69.0    male
# 34  35   Rows Noump    Six  88.0    male

# %%
new1_df=df.fillna(method='bfill')
new1_df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four  75.0  female
# 1    2     Max Ruin  Three  85.0    male
# 2    3       Arnold  Three  55.0    male
# 3    4   Krish Star   Four  60.0  female
# 4    5    John Mike   Four  60.0  female
# 5    6    Alex John   Four  55.0    male
# 6    7  My John Rob  Fifth  78.0    male
# 7    8       Asruid   Five  85.0    male
# 8    9      Tes Qry    Six  55.0    male
# 9   10     Big John   Four  55.0  female
# 10  11       Ronald    Six  94.0  female
# 11  12        Recky    Six  94.0  female
# 12  13          Kty  Seven  88.0  female
# 13  14         Bigy  Seven  88.0  female
# 14  15     Tade Row   Four  88.0    male
# 15  16        Gimmy   Four  88.0    male
# 16  17        Tumyu    Six  75.0    male
# 17  18        Honny   Five  75.0    male
# 18  19        Tinny   Nine  18.0    male
# 19  20       Jackly   Nine  65.0  female
# 20  21   Babby John   Four  55.0  female
# 21  22       Reggid  Seven  55.0  female
# 22  23        Herod  Eight  79.0    male
# 23  24    Tiddy Now  Seven  78.0    male
# 24  25     Giff Tow  Seven  79.0    male
# 25  26       Crelea  Seven  79.0  female
# 26  27     Big Nose  Three  86.0  female
# 27  28    Rojj Base  Seven  86.0  female
# 28  29  Tess Played  Seven  55.0    male
# 29  30    Reppy Red    Six  79.0  female
# 30  31  Marry Toeey   Four  88.0    male
# 31  32    Binn Rott  Seven  96.0  female
# 32  33    Kenn Rein    Six  96.0  female
# 33  34     Gain Toe  Seven  69.0    male
# 34  35   Rows Noump    Six  88.0     NaN

# %%
new_df=df.interpolate()
new_df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four  75.0  female
# 1    2     Max Ruin  Three  85.0    male
# 2    3       Arnold  Three  55.0    male
# 3    4   Krish Star   Four  60.0     NaN
# 4    5    John Mike   Four  60.0  female
# 5    6    Alex John   Four  55.0    male
# 6    7  My John Rob  Fifth  78.0    male
# 7    8       Asruid   Five  85.0    male
# 8    9      Tes Qry    Six  70.0    male
# 9   10     Big John   Four  55.0  female
# 10  11       Ronald    Six  74.5  female
# 11  12        Recky    Six  94.0  female
# 12  13          Kty  Seven  88.0  female
# 13  14         Bigy  Seven  88.0  female
# 14  15     Tade Row   Four  88.0    male
# 15  16        Gimmy   Four  88.0    male
# 16  17        Tumyu    Six  81.5    male
# 17  18        Honny   Five  75.0    male
# 18  19        Tinny   Nine  18.0    male
# 19  20       Jackly   Nine  65.0  female
# 20  21   Babby John   Four  60.0  female
# 21  22       Reggid  Seven  55.0  female
# 22  23        Herod  Eight  79.0    male
# 23  24    Tiddy Now    NaN  78.0    male
# 24  25     Giff Tow  Seven  78.5    male
# 25  26       Crelea  Seven  79.0     NaN
# 26  27     Big Nose  Three  82.5  female
# 27  28    Rojj Base  Seven  86.0  female
# 28  29  Tess Played  Seven  55.0    male
# 29  30    Reppy Red    Six  79.0  female
# 30  31  Marry Toeey   Four  88.0    male
# 31  32    Binn Rott  Seven  92.0  female
# 32  33    Kenn Rein    Six  96.0  female
# 33  34     Gain Toe  Seven  69.0    male
# 34  35   Rows Noump    Six  88.0     NaN

# %%
new_df=df.interpolate(method='time')
new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 new_df=df.interpolate(method='time')
#       2 new_df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:11855, in DataFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   11843 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
#   11844 def interpolate(
#   11845     self: DataFrame,
#    (...)
#   11853     **kwargs,
#   11854 ) -> DataFrame | None:
# > 11855     return super().interpolate(
#   11856         method,
#   11857         axis,
#   11858         limit,
#   11859         inplace,
#   11860         limit_direction,
#   11861         limit_area,
#   11862         downcast,
#   11863         **kwargs,
#   11864     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:7568, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7562 if isna(index).any():
#    7563     raise NotImplementedError(
#    7564         "Interpolation with NaNs in the index "
#    7565         "has not been implemented. Try filling "
#    7566         "those NaNs before interpolating."
#    7567     )
# -> 7568 new_data = obj._mgr.interpolate(
#    7569     method=method,
#    7570     axis=axis,
#    7571     index=index,
#    7572     limit=limit,
#    7573     limit_direction=limit_direction,
#    7574     limit_area=limit_area,
#    7575     inplace=inplace,
#    7576     downcast=downcast,
#    7577     **kwargs,
#    7578 )
#    7580 result = self._constructor(new_data)
#    7581 if should_transpose:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:422, in BaseBlockManager.interpolate(self, **kwargs)
#     421 def interpolate(self: T, **kwargs) -> T:
# --> 422     return self.apply("interpolate", **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1258, in Block.interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, downcast, **kwargs)
#    1255 data = self.values if inplace else self.values.copy()
#    1256 data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
# -> 1258 missing.interpolate_array_2d(
#    1259     data,
#    1260     method=method,
#    1261     axis=axis,
#    1262     index=index,
#    1263     limit=limit,
#    1264     limit_direction=limit_direction,
#    1265     limit_area=limit_area,
#    1266     fill_value=fill_value,
#    1267     **kwargs,
#    1268 )
#    1270 nb = self.make_block_same_class(data)
#    1271 return nb._maybe_downcast([nb], downcast)
#
# File ~\anaconda3\lib\site-packages\pandas\core\missing.py:249, in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     246 else:
#     247     assert index is not None  # for mypy
# --> 249     _interpolate_2d_with_fill(
#     250         data=data,
#     251         index=index,
#     252         axis=axis,
#     253         method=method,
#     254         limit=limit,
#     255         limit_direction=limit_direction,
#     256         limit_area=limit_area,
#     257         fill_value=fill_value,
#     258         **kwargs,
#     259     )
#     260 return
#
# File ~\anaconda3\lib\site-packages\pandas\core\missing.py:292, in _interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     290 if method == "time":
#     291     if not needs_i8_conversion(index.dtype):
# --> 292         raise ValueError(
#     293             "time-weighted interpolation only works "
#     294             "on Series or DataFrames with a "
#     295             "DatetimeIndex"
#     296         )
#     297     method = "values"
#     299 valid_limit_directions = ["forward", "backward", "both"]
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %%
new_df=df.dropna()
new_df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four  75.0  female
# 1    2     Max Ruin  Three  85.0    male
# 2    3       Arnold  Three  55.0    male
# 4    5    John Mike   Four  60.0  female
# 5    6    Alex John   Four  55.0    male
# 6    7  My John Rob  Fifth  78.0    male
# 7    8       Asruid   Five  85.0    male
# 9   10     Big John   Four  55.0  female
# 11  12        Recky    Six  94.0  female
# 12  13          Kty  Seven  88.0  female
# 13  14         Bigy  Seven  88.0  female
# 14  15     Tade Row   Four  88.0    male
# 15  16        Gimmy   Four  88.0    male
# 17  18        Honny   Five  75.0    male
# 18  19        Tinny   Nine  18.0    male
# 19  20       Jackly   Nine  65.0  female
# 21  22       Reggid  Seven  55.0  female
# 22  23        Herod  Eight  79.0    male
# 27  28    Rojj Base  Seven  86.0  female
# 28  29  Tess Played  Seven  55.0    male
# 29  30    Reppy Red    Six  79.0  female
# 30  31  Marry Toeey   Four  88.0    male
# 32  33    Kenn Rein    Six  96.0  female
# 33  34     Gain Toe  Seven  69.0    male
