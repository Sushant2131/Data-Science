# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('shopping.csv')
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.nunique()
# Out:
# Customer ID               3900
# Age                         53
# Gender                       2
# Item Purchased              25
# Category                     4
# Purchase Amount (USD)       81
# Location                    50
# Size                         4
# Color                       25
# Season                       4
# Review Rating               26
# Subscription Status          2
# Shipping Type                6
# Discount Applied             2
# Promo Code Used              2
# Previous Purchases          50
# Payment Method               6
# Frequency of Purchases       7
# dtype: int64

# %%
plt.figure(figsize = (20,4))
sns.countplot(x='Item Purchased',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Item Purchased', ylabel='count'>

# %% [markdown]
# From above plot we can see that male is purchesed more items then women.

# %%
plt.figure(figsize = (20,4))
sns.countplot(x='Category',hue='Season',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# From above plot we can see that male has frequently purchases items then women

# %%
sns.countplot(x='Frequency of Purchases',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Frequency of Purchases', ylabel='count'>

# %% [markdown]
# From above plot we can see men can frequently purchases items then the women

# %%
sns.countplot(x='Category',hue='Promo Code Used',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# From above figure we can see that most of the promo code will applied clothing

# %%
pd.crosstab(df['Location'],df['Subscription Status'])
# Out:
# Subscription Status  No  Yes
# Location
# Alabama              67   22
# Alaska               54   18
# Arizona              49   16
# Arkansas             59   20
# California           66   29
# Colorado             54   21
# Connecticut          62   16
# Delaware             58   28
# Florida              47   21
# Georgia              56   23
# Hawaii               46   19
# Idaho                74   19
# Illinois             70   22
# Indiana              58   21
# Iowa                 48   21
# Kansas               55    8
# Kentucky             53   26
# Louisiana            59   25
# Maine                58   19
# Maryland             66   20
# Massachusetts        49   23
# Michigan             57   16
# Minnesota            62   26
# Mississippi          59   21
# Missouri             54   27
# Montana              71   25
# Nebraska             62   25
# Nevada               57   30
# New Hampshire        54   17
# New Jersey           51   16
# ...

# %%
sns.countplot(x='Subscription Status',hue='Gender',data=df)
df['Subscription Status'].value_counts()
# Out:
# No     2847
# Yes    1053
# Name: Subscription Status, dtype: int64

# %% [markdown]
# From above plot we can see that men has more subscription then women and women has less numbers of subscriptions

# %%
sns.distplot(df['Age'],hist=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12304\43512197.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# From the figure we can see most of the customers in age of 20 to 70.

# %%
sns.displot(df['Purchase Amount (USD)'])

# %% [markdown]
# From figure we can see customers usually buy from range of 20$ to 100$.

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Payment Method',hue='Discount Applied',data=df)
# Out:
# <Axes: xlabel='Payment Method', ylabel='count'>

# %% [markdown]
# From above figure we can see that discount is less applied in all of the transactions

# %%
sns.barplot(x='Category',y='Review Rating',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Review Rating'>

# %% [markdown]
# From the bar diagram all the customers review is grater 3.5 and footware has bit high rating then other category.

# %%
plt.figure(figsize=(30,5))
sns.barplot(x='Location',y='Previous Purchases',data=df)
# Out:
# <Axes: xlabel='Location', ylabel='Previous Purchases'>
